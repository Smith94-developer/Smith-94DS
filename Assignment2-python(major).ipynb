# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(r'C:\Users\WELCOME\Downloads\honeyproduction 1998-2021.csv')
df
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
#1 How has honey production yield changed from 1998 to 2021 ?

import pandas as pd 
import matplotlib.pyplot as plt

average_yield = df.groupby('year')['yieldpercol'].mean()
plt.figure(figsize=(12,6))
average_yield.plot(kind='line',marker='o')
plt.title('Honey Production Yield (1998-2021)')
plt.xlabel('year')
plt.ylabel('yieldpercol')
plt.grid(True)
plt.show()

# %%
df.head()
df.info()
state_production = df.groupby('State')['totalprod'].sum().reset_index()
state_production = state_production.sort_values(by='totalprod', ascending=False)
plt.figure(figsize=(12, 6))
plt.bar(state_production['State'], state_production['totalprod'])
plt.xlabel('State')
plt.ylabel('Total Production')
plt.title('Honey Production by State')
plt.xticks(rotation=90)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
#2 Overtime, what are the major production trends across the states?
df.head()
df.info()
r2 = df.groupby('State')['totalprod'].sum().reset_index()
r2
r1 = r2.sort_values(by='totalprod', ascending=False)
r1
plt.figure(figsize=(18,12))
plt.barh(state_production['State'], state_production['totalprod'])

for i, totalprod in enumerate(r1['totalprod']):
plt.text(totalprod, i, str(totalprod), ha='left', va='center')

plt.xlabel('Total Production')
plt.ylabel('state')
plt.title('Honey Production by State')
plt.xticks(rotation=90)
plt.show()
# Out:
#   Cell In[2], line 12
#     plt.text(totalprod, i, str(totalprod), ha='left', va='center')
#     ^
# IndentationError: expected an indented block after 'for' statement on line 11

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
r2 = df.groupby('State')['totalprod'].sum().reset_index()
r2
# Out:
#              State    totalprod
# 0          Alabama   15282000.0
# 1          Arizona   39848000.0
# 2         Arkansas   54788000.0
# 3       California  457195000.0
# 4         Colorado   37904000.0
# 5          Florida  343697000.0
# 6          Georgia   80443000.0
# 7           Hawaii   25930000.0
# 8            Idaho   95207000.0
# 9         Illinois   11457000.0
# 10         Indiana   10772000.0
# 11            Iowa   48255000.0
# 12          Kansas   14305000.0
# 13        Kentucky    5353000.0
# 14       Louisiana   87527000.0
# 15           Maine    7235000.0
# 16        Maryland    1266000.0
# 17        Michigan  116067000.0
# 18       Minnesota  210530000.0
# 19     Mississippi   37065000.0
# 20        Missouri   17127000.0
# 21         Montana  265742000.0
# 22        Nebraska   69624000.0
# 23          Nevada    4832000.0
# 24      New Jersey    9631000.0
# 25      New Mexico    7147000.0
# 26        New York   87817000.0
# 27  North Carolina   12353000.0
# ...

# %%
r1 = r2.sort_values(by='totalprod', ascending=False)
r1
# Out:
#              State    totalprod
# 28    North Dakota  797000000.0
# 3       California  457195000.0
# 34    South Dakota  417516000.0
# 5          Florida  343697000.0
# 21         Montana  265742000.0
# 18       Minnesota  210530000.0
# 36           Texas  177325000.0
# 17        Michigan  116067000.0
# 42       Wisconsin  106716000.0
# 8            Idaho   95207000.0
# 26        New York   87817000.0
# 14       Louisiana   87527000.0
# 6          Georgia   80443000.0
# 22        Nebraska   69624000.0
# 40      Washington   68460000.0
# 43         Wyoming   60494000.0
# 31          Oregon   56699000.0
# 2         Arkansas   54788000.0
# 11            Iowa   48255000.0
# 1          Arizona   39848000.0
# 4         Colorado   37904000.0
# 19     Mississippi   37065000.0
# 32    Pennsylvania   26926000.0
# 37            Utah   26160000.0
# 7           Hawaii   25930000.0
# 29            Ohio   24662000.0
# 20        Missouri   17127000.0
# 0          Alabama   15282000.0
# ...

# %%
plt.figure(figsize=(18,12))
plt.barh(r1['State'], r1['totalprod'])

for i, totalprod in enumerate(r1['totalprod']):
    plt.text(totalprod, i, str(totalprod), ha='left', va='center')

plt.xlabel('Total Production')
plt.ylabel('state')
plt.title('Honey Production by State')
plt.xticks(rotation=90)
plt.show()

# %%
#3 Does the data show any trends in terms of the number of honey producing colonies and yield per colony before 2006, which was when concern over Colony Collapse Disorder spread nationwide?

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
filtered_data = df[df['year'] < 2006]
filtered_data
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 338       Virginia    8000.0           37    296000.0     59000.0        2.20
# 339     Washington   51000.0           55   2805000.0   1935000.0        1.01
# 340  West Virginia    8000.0           51    408000.0    102000.0        1.29
# 341      Wisconsin   64000.0           83   5312000.0   2922000.0        1.14
# 342        Wyoming   40000.0           56   2240000.0    291000.0        0.89
#
#       prodvalue  year
# ...

# %%
grouped_data = filtered_data.groupby('year').agg({'numcol': 'sum', 'yieldpercol': 'mean'}).reset_index()
grouped_data
# Out:
#    year     numcol  yieldpercol
# 0  1998  2621000.0    69.953488
# 1  1999  2637000.0    65.465116
# 2  2000  2604000.0    67.581395
# 3  2001  2542000.0    64.545455
# 4  2002  2565000.0    66.795455
# 5  2003  2591000.0    62.545455
# 6  2004  2539000.0    64.804878
# 7  2005  2394000.0    64.268293

# %%
plt.figure(figsize=(10, 6))
plt.plot(grouped_data.index, grouped_data['numcol'], label='Number of Colonies')
plt.plot(grouped_data.index, grouped_data['yieldpercol'], label='Yield per Colony')
plt.xlabel('Year')
plt.ylabel('yieldpercol')
plt.title('Trends in Honey Production')
plt.legend()
plt.show()

# %%
# Plotting the trends
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['year'], grouped_data['numcol'])
plt.bar(grouped_data['year'], grouped_data['yieldpercol'])
plt.xlabel('Year')
plt.ylabel('yieldpercol')
plt.title('Trends in Honey Production')
 
plt.show()

# %%
#4 Are there any patterns that can be observed between total honey production and value of production every year?
df['year'] = pd.to_datetime(df['year'], format='%Y')

# %%
s1 = df.groupby(df['year']).sum().reset_index()
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_4784\1200084021.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   s1 = df.groupby(df['year']).sum().reset_index()

# %%
plt.plot(s1['year'], s1['totalprod'], label='Total Honey Production')
plt.plot(s1['year'], s1['prodvalue'], label='Value of Production')
plt.xlabel('Year')
plt.ylabel('prodvalue')
plt.title('Total Honey Production vs. Value of Production')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(s1.index, s1['totalprod'], label='Total Honey Production',color='brown')
plt.bar(s1.index, s1['prodvalue'], label='Value of Production',color='green', alpha=0.5)
plt.xlabel('Year')
plt.ylabel('prodvalue')
plt.title('Total Honey Production vs. Value of Production')
plt.legend()
plt.show()

# %%
#5
df.head()
# Out:
#         State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1     Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2    Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3  California  450000.0           83  37350000.0  12326000.0        0.62
# 4    Colorado   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(r'C:\Users\WELCOME\Downloads\honeyproduction 1998-2021.csv')
df
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
df.head()
# Out:
#         State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1     Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2    Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3  California  450000.0           83  37350000.0  12326000.0        0.62
# 4    Colorado   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
df.year.head(985)
# Out:
# 0      1998
# 1      1998
# 2      1998
# 3      1998
# 4      1998
#        ...
# 980    2021
# 981    2021
# 982    2021
# 983    2021
# 984    2021
# Name: year, Length: 985, dtype: int64

# %%
df_grouped = df.groupby(df['year'])['prodvalue'].sum()
df_grouped
# Out:
# year
# 1998    146091000.0
# 1999    123657000.0
# 2000    131568000.0
# 2001    132282000.0
# 2002    227302000.0
# 2003    252079000.0
# 2004    197307000.0
# 2005    160793000.0
# 2006    157924000.0
# 2007    161356000.0
# 2008    229992000.0
# 2009    213920000.0
# 2010    278370000.0
# 2011    258688000.0
# 2012    280725000.0
# 2013    315118000.0
# 2014    384483000.0
# 2015    322505000.0
# 2016    325557000.0
# 2017    317502000.0
# 2018    324883000.0
# 2019    297120000.0
# 2020    297177000.0
# 2021    314413000.0
# Name: prodvalue, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df_grouped.index, df_grouped.values, marker='o', color='k')
ax = plt.gca()
ax.set_facecolor("cyan")
plt.xlabel('Year')
plt.ylabel('Production Value')
plt.title('Changes in Production Value over the Years')
plt.show()

# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r'C:\Users\WELCOME\Downloads\honeyproduction 1998-2021.csv')

df1
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
sns.scatterplot(data=df, x='stocks', y='priceperlb')
plt.title("stocks vs priceperlb")
plt.show()

# %%
#6
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(r'C:\Users\WELCOME\Downloads\honeyproduction 1998-2021.csv')
df
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
plt.figure(figsize=(12,6), facecolor= 'plum')
sns.barplot(data=df, x='year', y='stocks')
plt.title('Stocks by Year')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(df['year'],df['stocks'])

plt.xlabel('year')
plt.ylabel('stocks')
plt.title('year vs stocks')
plt.xticks(range(1998,2022),rotation=90)
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(r'C:\Users\WELCOME\Downloads\honeyproduction 1998-2021.csv')
df
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
plt.figure(figsize=(12,6),facecolor='lightblue')
sns.barplot(data=df, x='year', y='yieldpercol')
plt.title('yieldpercol over the years')
plt.xticks(rotation=360)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6),facecolor='lightgreen')
sns.barplot(data=df, x='year', y='numcol')
plt.title(' numcol with the years')
plt.xticks(rotation=360)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6),facecolor='lightpink')
sns.barplot(data=df, x='State', y='prodvalue')
plt.title(' State with the prodvalue')
plt.xticks(rotation=100)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6),facecolor='lavender')
sns.barplot(data=df, x='year', y='priceperlb')
plt.title(' priceperlb with the year')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
df.stocks.head(985)
# Out:
# 0        159000.0
# 1       1485000.0
# 2       1688000.0
# 3      12326000.0
# 4       1594000.0
#           ...
# 980       79000.0
# 981     1206000.0
# 982      136000.0
# 983      750000.0
# 984      242000.0
# Name: stocks, Length: 985, dtype: float64
